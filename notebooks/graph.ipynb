# %%
import pandas as pd
from igraph import Graph, plot

# %%
products = pd.read_csv('../data/sku.csv')
matches = pd.read_csv('../data/batch_selection.csv').rename(columns={'id1': 'src', 'id2': 'dst'})

# %%
products.head()
# Out:
#    level_0  index          id  \
# 0        4     28  1213084979
# 1        9     82  1883453832
# 2       10     85  1267104656
# 3       11     97  1266887860
# 4       12    100  1229857214
#
#                                                 name  \
# 0  Cream Cheese / Krim keju Murray Goulburn 2KG A...
# 1  Jual Keju Anchor Mozarella 2Kg Cheese Mozzarel...
# 2                    Promo Prochiz Gold 2 KG Limited
# 3  Limit edition KEJU KRAFT CHEDDAR MARTABAK 2 KG...
# 4  Keju mozzarella Anchor 1kg /Repack 1kg Mozzare...
#
#                                          description   price  weight  \
# 0  \nCream Cheese Murray Goulburn\n\nOrigin Austr...  201500    2000
# 1  \nKeju Anchor Mozarella 2Kg\n\nPacking pabrik ...  267300    1375
# 2  \nKeju Prochiz Gold Cheddar cocok digunakan un...  128700    2000
# 3  \nkraft cheddar martabak 2kg\nBisa Kirim JNE /...  171600    2000
# 4  Repack 1kg Dari block besar  Keju akan dikirim...  136500    2000
#
# ...

# %%
g = Graph()

# %%
g.add_vertices(len(products))

# %%
id_mapping = dict(zip(products.id, range(len(products))))

# %%
g.add_edges([[id_mapping[id] for id in match[['src', 'dst']].tolist()] for i, match in matches.iterrows() if match.match == 1])

# %%
g.vs['id'] = products.id.values
g.vs['name'] = products.id.name

# %%
g.vs[0].attributes()
# Out:
# {'id': 1213084979, 'name': 'id'}

# %%
list(g.clusters())
# Out:
# [[0, 49, 94, 135, 194, 210, 458],
#  [1, 10, 40, 60, 89, 312],
#  [2, 152, 204, 261, 293, 445],
#  [3, 56, 57, 113, 174, 247, 281],
#  [4, 17, 35, 51, 254, 454],
#  [5, 70, 91, 141, 219, 222, 230, 251, 288, 455],
#  [6],
#  [7],
#  [8],
#  [9, 103, 140, 151, 187, 202, 209, 233, 292, 379],
#  [11, 50, 115, 347, 356, 362, 384],
#  [12],
#  [13, 18, 107, 117, 176, 208, 373],
#  [14, 39, 63, 77, 96, 144, 155, 193, 366],
#  [15],
#  [16, 184, 244],
#  [19],
#  [20, 127, 367],
#  [21],
#  [22],
#  [23],
#  [24],
#  [25, 36, 42, 75, 79, 123, 192, 433, 451],
#  [26, 83, 164],
#  [27],
#  [28, 31, 44, 47, 90, 110, 175, 201, 305],
#  [29, 34, 166, 186, 189, 216, 263, 285, 377, 460, 461, 462, 467],
#  [30],
#  [32],
#  [33, 98, 101, 143, 158, 238, 278, 372],
#  [37, 52, 73, 236, 395, 396, 439, 447, 456],
#  [38],
#  [41, 78, 80, 214, 435, 450],
#  [43, 45, 69, 81, 172, 258, 420, 423],
#  [46, 53, 92, 104, 120, 150, 157, 226, 252, 274, 287, 383],
#  [48, 61, 153, 243, 300, 350, 365],
#  [54],
# ...

# %%
layout = g.layout("kk")
plot(g, layout=layout)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-78115617a1c3> in <module>
#       1 layout = g.layout("kk")
# ----> 2 plot(g, layout=layout)
#
# /opt/conda/lib/python3.7/site-packages/igraph/drawing/__init__.py in plot(obj, target, bbox, *args, **kwds)
#     484         bbox = BoundingBox(bbox)
#     485
# --> 486     result = Plot(target, bbox, background=kwds.get("background", "white"))
#     487
#     488     if "margin" in kwds:
#
# /opt/conda/lib/python3.7/site-packages/igraph/drawing/__init__.py in __init__(self, target, bbox, palette, background)
#     119         """
#     120         self._filename = None
# --> 121         self._surface_was_created = not isinstance(target, cairo.Surface)
#     122         self._need_tmpfile = False
#     123
#
# /opt/conda/lib/python3.7/site-packages/igraph/drawing/utils.py in __getattr__(self, _)
#     412
# ...
