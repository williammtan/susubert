# %%
import pandas as pd
import spacy
import re
from tqdm import tqdm

# %%
# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# %%bigquery products --use_bqstorage_api
# SELECT id, name, description, weight, shop_id, price, menu_name, main_category, sub_category
# FROM `food-id-app.external_data_temp.EXTERNAL_PRODUCTS`
# WHERE main_category = 'Produk Susu'
# Out:
# ...
# Downloading: 100%|██████████| 425807/425807 [00:02<00:00, 179351.87rows/s]

# %%
products = products[products.sub_category == 'Susu UHT'].reset_index(drop=True)

# %%
nlp = spacy.blank('id')
brief_cleaning = [re.sub("[^A-Za-z0-9/']+", ' ', str(title)).lower()
                    for title in tqdm(products.description.values)]
# Out:
# 100%|██████████| 47196/47196 [00:00<00:00, 48229.24it/s]

# %%
brief_cleaning
# Out:
# ['isi 6pcs ukuran 1liter expired masih lamaaa produk baru ',
#  'susu uht diamond 1 liter coklat 1pcs',
#  'susu diamond uht full cream 1liter harga grosir minimum 12 pc',
#  'selamat berbelanja di senzoshop semua barang ready ya agan dan sista buruan diorder harga untuk kemasan 1 liter merupakan susu uhtmerek diamond memiliki expired panjang expired rata 34 adalah 1 tahun dapat disimpan diluar kulkas jika belum dibuka dengan suhu ruangan yang tidak lembab pengiriman setiap hari disarankan menggunakan instant courier untuk menjaga kualitas produk atau instant 1 3 jam tergantung jarak atau sameday 3 8 jam senzoshop menyediakan berbagai macam produk dengan harga oke',
# ...

# %%
text = [cleaning_title(doc) for doc in tqdm(
    nlp.pipe(brief_cleaning, batch_size=5000, n_process=-1), total=len(brief_cleaning))]

titles = np.array([title.split()
                    for title in text if title is not None], dtype=object)
words = np.array([word for title in tqdm(titles)
                    for word in title], dtype=object)
